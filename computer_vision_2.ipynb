# %% [markdown]
# <a href="https://colab.research.google.com/github/jainhimani1999/MachineLearning/blob/master/computer_vision_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread('scenary-3.jpg')

# %%
scaleX = 0.9
scaleY = 0.9
scaleUp = cv2.resize(image, None, fx= scaleX*3, fy= scaleY*3, interpolation= cv2.INTER_LINEAR)

# %%
cv2_imshow(scaleUp)
# Out:
# <PIL.Image.Image image mode=RGB size=610x602 at 0x7F4EEB2E17B8>

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=226x223 at 0x7F4EEB2E19E8>

# %%
scaleUp1 = cv2.resize(image[100:150,100:150], None, fx= scaleX*5, fy= scaleY*5, interpolation= cv2.INTER_LINEAR)

# %%
cv2_imshow(scaleUp1)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F4EEB2E1B00>

# %%
x=image[100:150,100:150]

# %%
import numpy as np
image=np.delete(image,x)

# %%
scaleUp2 = cv2.resize(image,None, fx= scaleX*3, fy= scaleY*3, interpolation= cv2.INTER_LINEAR)

# %%
cv2_imshow(scaleUp2)
# Out:
# <PIL.Image.Image image mode=L size=3x407616 at 0x7F4EEB2E1C18>
