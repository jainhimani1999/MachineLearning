# %% [markdown]
# <a href="https://colab.research.google.com/github/jainhimani1999/MachineLearning/blob/master/computer_vision_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image1=cv2.imread('scenary-1.jpg')
image2=cv2.imread('scenary-2.jpg')

# %%
#resizing image2 to become equal to image1
image2 = cv2.resize(image2,(300,168), interpolation = cv2.INTER_AREA)

# %%
image2.shape
# Out:
# (168, 300, 3)

# %%
image1.shape
# Out:
# (168, 300, 3)

# %%
new_sub=image1-image2

# %%
cv2_imshow(new_sub)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F95917CEA58>

# %%
new_sub1=image2-image1

# %%
cv2_imshow(new_sub1)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F95916657F0>

# %%
new_sum1=image1+image2

# %%
cv2_imshow(new_sum1)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F95916657F0>
